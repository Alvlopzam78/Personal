# %%
import numpy as np
import scipy as sp
import pandas as pd
from numpy import math
from pandas import DataFrame
import statistics
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Ejercicio Data Frame

# %%
df=pd.read_excel("DatosEmpleo2021.xlsx")
df
# Out:
#     Unnamed: 0               Nombre                         Puesto  \
# 0            0           Airi Satou                     Accountant
# 1            1       Angelica Ramos  Chief Executive Officer (CEO)
# 2            2           Ashton Cox        Junior Technical Author
# 3            3        Bradley Greer              Software Engineer
# 4            4       Brenden Wagner              Software Engineer
# 5            5   Brielle Williamson         Integration Specialist
# 6            6           Bruno Nash              Software Engineer
# 7            7         Caesar Vance              Pre/Sales Support
# 8            8         Cara Stevens                Sales Assistant
# 9            9         Cedric Kelly    Senior Javascript Developer
# 10          10      Charde Marshall              Regional Director
# 11          11        Colleen Hurst           Javascript Developer
# 12          12             Dai Rios                 Personnel Lead
# ...

# %%
Tokyo=df.query('Sucursal=="Tokyo"')
len(Tokyo)
# Out:
# 5

# %%
Tokyo
# Out:
#     Unnamed: 0           Nombre                  Puesto Sucursal  Edad  \
# 0            0       Airi Satou              Accountant    Tokyo    33
# 17          17  Garrett Winters              Accountant    Tokyo    63
# 41          41   Rhona Davidson  Integration Specialist    Tokyo    55
# 42          42  Sakura Yamamoto        Support Engineer    Tokyo    37
# 45          45        Shou Itou      Regional Marketing    Tokyo    20
#
#    Fecha de Contratación   Año  Mes  Día  Salario
# 0             28/11/2008  2008   11   28   162700
# 17            25/07/2011  2011    7   25   170750
# 41            14/10/2010  2010   10   14   327900
# 42            19/08/2009  2009    8   19   139575
# 45            14/08/2011  2011    8   14   163000

# %%
df.query('(Sucursal=="Tokyo" or Sucursal=="Sidney") and Edad>30' )
# Out:
#     Unnamed: 0           Nombre                  Puesto Sucursal  Edad  \
# 0            0       Airi Satou              Accountant    Tokyo    33
# 17          17  Garrett Winters              Accountant    Tokyo    63
# 36          36   Michelle House  Integration Specialist   Sidney    37
# 41          41   Rhona Davidson  Integration Specialist    Tokyo    55
# 42          42  Sakura Yamamoto        Support Engineer    Tokyo    37
# 45          45        Shou Itou      Regional Marketing    Tokyo    20
#
#    Fecha de Contratación   Año  Mes  Día  Salario
# 0             28/11/2008  2008   11   28   162700
# 17            25/07/2011  2011    7   25   170750
# 36            02/06/2011  2011    6    2    95400
# 41            14/10/2010  2010   10   14   327900
# 42            19/08/2009  2009    8   19   139575
# 45            14/08/2011  2011    8   14   163000

# %%
df["Edad"].max()
# Out:
# 66

# %%
df.query('Edad==66')
# Out:
#     Unnamed: 0         Nombre                   Puesto       Sucursal  Edad  \
# 2            2     Ashton Cox  Junior Technical Author  San Francisco    66
# 35          35  Michael Silva       Marketing Designer         London    66
#
#    Fecha de Contratación   Año  Mes  Día  Salario
# 2             12/01/2009  2009    1   12    86000
# 35            27/11/2012  2012   11   27   198500

# %%
df.query('Año==2011')
# Out:
#     Unnamed: 0             Nombre                  Puesto       Sucursal  \
# 4            4     Brenden Wagner       Software Engineer  San Francisco
# 6            6         Bruno Nash       Software Engineer         London
# 7            7       Caesar Vance       Pre/Sales Support       New York
# 8            8       Cara Stevens         Sales Assistant       New York
# 13          13       Donna Snider        Customer Support       New York
# 17          17    Garrett Winters              Accountant          Tokyo
# 22          22    Hermione Butler       Regional Director         London
# 28          28   Jenette Caldwell        Development Lead       New York
# 33          33     Martena Mccray      Post/Sales support      Edinburgh
# 34          34      Michael Bruce    Javascript Developer      Singapore
# 36          36     Michelle House  Integration Specialist         Sidney
# 37          37       Olivia Liang        Support Engineer      Singapore
# ...

# %%
df[df["Edad"]==df["Edad"].max()]
# Out:
#     Unnamed: 0         Nombre                   Puesto       Sucursal  Edad  \
# 2            2     Ashton Cox  Junior Technical Author  San Francisco    66
# 35          35  Michael Silva       Marketing Designer         London    66
#
#    Fecha de Contratación   Año  Mes  Día  Salario
# 2             12/01/2009  2009    1   12    86000
# 35            27/11/2012  2012   11   27   198500

# %%
hist(df["Edad"])
# Out:
# (array([9., 4., 5., 5., 6., 8., 3., 3., 5., 9.]),
#  array([19. , 23.7, 28.4, 33.1, 37.8, 42.5, 47.2, 51.9, 56.6, 61.3, 66. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Ejercicio 63
