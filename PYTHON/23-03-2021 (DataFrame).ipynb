# %%
import numpy as np
import scipy as sp
import pandas as pd
from numpy import math
from pandas import DataFrame
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: MacOSX
# Populating the interactive namespace from numpy and matplotlib

# %%
dic={"Nombre":("José","Ricardo","Sarah","Ximena"),"Carrera":("Derecho","Matemáticas Aplicadas","Ciencia Política","Actuaría"),"Edad":(18,19,18,18),"Semestre":(5,2,2,1)}

# %%
df=pd.DataFrame(dic) #Converitr mi diccionario en un DataFrame

# %%
df
# Out:
#     Nombre                Carrera  Edad  Semestre
# 0     José                Derecho    18         5
# 1  Ricardo  Matemáticas Aplicadas    19         2
# 2    Sarah       Ciencia Política    18         2
# 3   Ximena               Actuaría    18         1

# %%
df[0:2] #Extraer renglones de la tabla
# Out:
#     Nombre                Carrera  Edad  Semestre
# 0     José                Derecho    18         5
# 1  Ricardo  Matemáticas Aplicadas    19         2

# %%
df.max()
# Out:
# Nombre                     Ximena
# Carrera     Matemáticas Aplicadas
# Edad                           19
# Semestre                        5
# dtype: object

# %%
df.min()
# Out:
# Nombre          José
# Carrera     Actuaría
# Edad              18
# Semestre           1
# dtype: object

# %%
df.mean() #Solo toma los campos numéricos
# Out:
# Edad        18.25
# Semestre     2.50
# dtype: float64

# %%
df["Semestre"].mean() #Medio de un campo específico
# Out:
# 2.5

# %%
df.describe() #Muestra información estadística general de los datos numéricos de la tabla
# Out:
#         Edad  Semestre
# count   4.00  4.000000
# mean   18.25  2.500000
# std     0.50  1.732051
# min    18.00  1.000000
# 25%    18.00  1.750000
# 50%    18.00  2.000000
# 75%    18.25  2.750000
# max    19.00  5.000000

# %%
df.sort_values(by="Semestre") #Ordenar la información de acuerdo a cierto campo
# Out:
#     Nombre                Carrera  Edad  Semestre
# 3   Ximena               Actuaría    18         1
# 1  Ricardo  Matemáticas Aplicadas    19         2
# 2    Sarah       Ciencia Política    18         2
# 0     José                Derecho    18         5

# %%
df.sort_values(by="Semestre", ascending=False) #Orden descendente
# Out:
#     Nombre                Carrera  Edad  Semestre
# 0     José                Derecho    18         5
# 1  Ricardo  Matemáticas Aplicadas    19         2
# 2    Sarah       Ciencia Política    18         2
# 3   Ximena               Actuaría    18         1

# %%
df["Semestre"]>=2 #Especifico un criterio de mi interes en un campo específico
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# Name: Semestre, dtype: bool

# %%
df[df["Semestre"]>=2]
# Out:
#     Nombre                Carrera  Edad  Semestre
# 0     José                Derecho    18         5
# 1  Ricardo  Matemáticas Aplicadas    19         2
# 2    Sarah       Ciencia Política    18         2

# %%
df[df["Semestre"]>2] #Obtener una lista de los registros que cumplen la condición
# Out:
#   Nombre  Carrera  Edad  Semestre
# 0   José  Derecho    18         5

# %%
ls
# Out:
# 23-03-2021 (DataFrame).ipynb
# Cuaderno 02-02-2021.ipynb
# Cuaderno 04-03-2021 (lectura de archivos).ipynb
# Cuaderno 09-02-2021.ipynb
# Cuaderno 11-02-2021.ipynb
# Cuaderno 14-01.ipynb
# Cuaderno 16-02-2021.ipynb
# Cuaderno 16-03-2021 (gráficas).ipynb
# Cuaderno 18-02-2021.ipynb
# Cuaderno 18-03-2021 (Arreglos).ipynb
# Cuaderno 19-01-21.ipynb
# Cuaderno 21-01-21.ipynb
# Cuaderno 26-01-21.ipynb
# Cuaderno 28-01-2021.ipynb
# Cuaderno 4-02-2021.ipynb
# Edades.txt
# Ejercicio 16.ipynb
# Ejercicio 21.ipynb
# Ejercicio 52 d.ipynb
# Ejercicios y Problemas (4).ipynb
# Exámenes/
# Problema Diccionarios.ipynb
# Prueba.ipynb
# Sistema de Ecuaciones 2.ipynb
# SorJuana.txt
# Tarea 2 manejo de texto (str).ipynb
# Tarea 3 Listas.ipynb
# Tarea_1_LópezZamora.ipynb
# ciudades.csv
# cuaderno 9-03-2021 (repaso).ipynb
# datos.txt
# datosEmpleo.csv
# inflac.txt
# listado.txt
# nombres.txt
# sueldos.txt
# tipoUSD.txt

# %%
df2=pd.read_csv("datosEmpleo.csv",header=0) #De pandas utiliza la instruccion lee archivos csv y toma como encabezado o nombres de campo el renglon 0 (primer renglón del archivo)

# %%
df2 #Muestra la tabla de los datos en el campo que corresponden
# Out:
#                    Name                       Position         Office  Age  \
# 0            Airi Satou                     Accountant          Tokyo   33
# 1        Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2            Ashton Cox        Junior Technical Author  San Francisco   66
# 3         Bradley Greer              Software Engineer         London   41
# 4        Brenden Wagner              Software Engineer  San Francisco   28
# 5    Brielle Williamson         Integration Specialist       New York   61
# 6            Bruno Nash              Software Engineer         London   38
# 7          Caesar Vance              Pre/Sales Support       New York   21
# 8          Cara Stevens                Sales Assistant       New York   46
# 9          Cedric Kelly    Senior Javascript Developer      Edinburgh   22
# 10      Charde Marshall              Regional Director  San Francisco   36
# ...

# %%
df2.info() #Sirve para analizar el timpo de información de cada columna y ver que es una tabala homogénea
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        57 non-null     object
#  1   Position    57 non-null     object
#  2   Office      57 non-null     object
#  3   Age         57 non-null     int64
#  4   Start date  57 non-null     object
#  5   year        57 non-null     int64
#  6   month       57 non-null     int64
#  7   day         57 non-null     int64
#  8   Salary      57 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 4.1+ KB

# %%
#Cambio los nombres de los encabezados a español
campos=("Nombre","Puesto","Sucursal","Edad","Fecha de Contratación","Año","Mes","Día","Salario")
df3=pd.read_csv("datosEmpleo.csv",header=0,names=campos)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nombre                 57 non-null     object
#  1   Puesto                 57 non-null     object
#  2   Sucursal               57 non-null     object
#  3   Edad                   57 non-null     int64
#  4   Fecha de Contratación  57 non-null     object
#  5   Año                    57 non-null     int64
#  6   Mes                    57 non-null     int64
#  7   Día                    57 non-null     int64
#  8   Salario                57 non-null     int64
# dtypes: int64(5), object(4)
# memory usage: 4.1+ KB

# %%
df3.describe()
# Out:
#             Edad          Año        Mes        Día       Salario
# count  57.000000    57.000000  57.000000  57.000000  5.700000e+01
# mean   42.736842  2010.228070   7.210526  14.192982  2.521353e+05
# std    14.877507     1.476211   3.682666   8.244995  2.153847e+05
# min    19.000000  2008.000000   1.000000   1.000000  7.565000e+04
# 25%    30.000000  2009.000000   4.000000   9.000000  1.120000e+05
# 50%    42.000000  2010.000000   8.000000  13.000000  1.645000e+05
# 75%    56.000000  2011.000000  10.000000  21.000000  3.279000e+05
# max    66.000000  2013.000000  12.000000  29.000000  1.200000e+06

# %% [markdown]
# # Tarea: Ejercicio 66
